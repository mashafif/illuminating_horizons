# %%
# Libraries
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import requests
import zipfile
from shapely.geometry import LineString

# %%
geojson_file = '/Users/yuji/code/illuminating_horizons/illuminating_horizons/data_exploration/power_grid_california.geojson'
power_grid = gpd.read_file(geojson_file)
power_grid.head(100)
# Out:
#                    id                @id FIXME Status addr:street bridge  \
# 0   relation/17193424  relation/17193424  None   None        None   None
# 1       way/205444360      way/205444360  None   None        None   None
# 2         way/5437364        way/5437364  None   None        None   None
# 3         way/5438492        way/5438492  None   None        None   None
# 4         way/5453903        way/5453903  None   None        None   None
# ..                ...                ...   ...    ...         ...    ...
# 95       way/10259909       way/10259909  None   None        None   None
# 96       way/10260372       way/10260372  None   None        None   None
# 97       way/10261065       way/10261065  None   None        None   None
# 98       way/10263732       way/10263732  None   None        None   None
# 99       way/10264442       way/10264442  None   None        None   None
#
#    bridge:name bridge_ref bridge_type building  ... transformer tunnel  \
# ...

# %%
geojson_file_two = '/Users/yuji/code/illuminating_horizons/illuminating_horizons/data_exploration/california_squared.geojson'
california_squared = gpd.read_file(geojson_file_two)
california_squared.head()
# Out:
#    grid_id                                           geometry
# 0        1  POLYGON ((-117.06914 32.62134, -116.86507 32.6...
# 1        2  POLYGON ((-116.86507 32.62134, -116.66101 32.6...
# 2        3  POLYGON ((-116.66101 32.62134, -116.45694 32.6...
# 3        4  POLYGON ((-116.45694 32.62134, -116.25287 32.6...
# 4        5  POLYGON ((-116.25287 32.62134, -116.06719 32.6...

# %%
from geodata_processing import download_gdf

# %%
usa_gdf = download_gdf('USA',1)

# %%
california_gdf = usa_gdf[usa_gdf['NAME_1'] == "California"]

# %%
california_gdf
# Out:
#      GID_1 GID_0       COUNTRY      NAME_1  VARNAME_1 NL_NAME_1 TYPE_1  \
# 4  USA.5_1   USA  UnitedStates  California  CA|Calif.        NA  State
#
#   ENGTYPE_1 CC_1 HASC_1  ISO_1  \
# 4     State   NA  US.CA  US-CA
#
#                                             geometry
# 4  MULTIPOLYGON (((-117.23300 32.77420, -117.2336...

# %%
power_grid = gdf.sjoin(california_gdf, how='inner')

# %%
power_grid
# Out:
#                       id                @id FIXME Status addr:street bridge  \
# 0      relation/17193424  relation/17193424  None   None        None   None
# 1          way/205444360      way/205444360  None   None        None   None
# 2            way/5437364        way/5437364  None   None        None   None
# 3            way/5438492        way/5438492  None   None        None   None
# 4            way/5453903        way/5453903  None   None        None   None
# ...                  ...                ...   ...    ...         ...    ...
# 34694     way/1306302669     way/1306302669  None   None        None   None
# 34695     way/1306302670     way/1306302670  None   None        None   None
# 34696     way/1306302671     way/1306302671  None   None        None   None
# 34697     way/1306302677     way/1306302677  None   None        None   None
# 34698     way/1306302678     way/1306302678  None   None        None   None
#
# ...
